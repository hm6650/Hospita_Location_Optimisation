# %% [markdown]
# ### Let's time travel to May 17, 1642...
#
#
# The city of Montreal was just built to accommodate the growing population, the people of the city have not yet received any public facilities such as hospitals, schools, etc. In response to the need of the people, the government decides to prioritize construction of hospitals.
#
# When comparing the locations for developing new medical facilities, they decide to take into consideration the level of medical assistance required per age categories,the feasibility of access, the number of patients visiting a hospital, and the expected demand. In this project, we will develop a location optimization model to integrate these key factors and help decision-makers identify the most strategic location to build the hospital(s).
#
# The model was designed to operate at the outward level of a postal code, where the population is grouped per outward code. The objective of the hospital location optimization model is to build facilities in high demand markets to optimize population’s access to this service (maximization problem). The demand is calculated as a function of population density per age category in a particular outward code weighted by the level of medical assistance required.
#
# Since the city is built from scratch, the government has to build different kinds of facilities to accomodate people's needs. Therefore there is a restriction on the budget availability, number of hospitals built,and hospital capacity.

# %% [markdown]
# ### Scope

# %% [markdown]
# These different sectors are broken down by the outward section of the postal codes (i.e., the first three digits of the postal code before the space in the middle); within Montreal, there are a total of 116 outward codes.
#
# The age groups are broken down into the four following groups: 0 – 14-year-olds, 15 – 64-year-olds, 65 – 84-year-olds, 85+ year olds.

# %% [markdown]
# # Import Packages

# %%
###Importing required library
import pandas as pd
import numpy as np
import gurobipy as gb
from gurobipy import GRB
from gurobipy import *

# %%
###file directory path for importing the dataset
import os
os.chdir(r'C:/Users/hp/OneDrive/Desktop/MMA/Fall 2022/MGSC 662 Decision Analytics/Assignment/Group assignment')

# %% [markdown]
# # Load and Analyze Required Data

# %%
###Datasets for coding
#population dataset
df = pd.read_csv("Population_Density_data.csv")
df_new = df[["0 to 14 years","15 to 64 years","65-84 years","85 years and over"]]
###postal code names
postal_code = df[["Postal Code"]]
####ditance between postal codes
#dist = [116*116] matrix
df2 = pd.read_excel("distance_matrix_int.xlsx")
df2 = df2.iloc[:,1:]

# %%
age = ["0-14yrs","15-64yrs","65-84yrs","85+yrs"]   ##age categories

med_assist = [0.6,0.3,0.7,0.8]  ###percentage of population that requires frequent medical asistance

pop_den = df_new.to_numpy()     ###population density matrix

Tot_pop = pop_den.sum(axis=1)   ##total population

postal_code = postal_code.to_numpy()    ##postalcode matrix

post_dist = df2.to_numpy()
post_dist = post_dist.astype(int)    ###distance between postal codes

###cost constraints
budget = 9000       ##Budget in million
FC_hos = 500         ##Fixed cost in million
VC_bed = 1           ##Variable cost in million

# %% [markdown]
# # Optimizing Model

# %% [markdown]
# ### Decision Variables

# %%
###Decision variables 
prob = gb.Model('Hospital Construction Optimization')
I = len(postal_code)
J = len(age)


###indicates where a hospital should be built in that postal code
X = prob.addVars(I, vtype = GRB.BINARY, name = [str(i) for i in postal_code])

###indicates the number of beds allocated to a hospital
B = prob.addVars(I, vtype = GRB.INTEGER, lb = 0, ub = 1000, name = ['Number of beds in ' + str(i) for i in postal_code])

##indicates which hospital doe people from location i access
Aux = prob.addVars(I,I,vtype = GRB.BINARY, name=["people from " +str(i) + "visits" +str(j) for i in postal_code for j in postal_code ])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-09-15

# %% [markdown]
# Maximizing the service accessibility of hospitals for the most required age group based on the level of medical assistance required age-wise
#
# $$\max \sum_{i,j} (X_i * P_{i,j} * A_j) +(Aux_i * P_{i,j} * A_j) $$

# %%
###objective function
###maximize the medical assistanceship received to the population 

prob.setObjective(sum((X[i] * pop_den [i,j] * med_assist[j]+(pop_den [i,j] * Aux[i,j] * med_assist[j])) for i in range(I) for j in range (J)), GRB.MAXIMIZE)

# %% [markdown]
# ### Constraints
#
# The model has 350 constraints

# %%
#Aux[i][j]:-Aux[people location][hospital location]

#Budget constraint
prob.addConstr(sum(X[i] * FC_hos + B[i] * VC_bed for i in range(I)) <= budget,name='Budget') 

#At least 12 hospitals in the city
prob.addConstr(sum(X[i] for i in range(I))>=12, name='Max number of hospital required')    

##the variable cost should be included only if the hospital is present in that location 
for i in range(I):
    prob.addConstr(B[i] <=(100000*X[i]),name="Beds only if hopsital is present")
    

##people from every postal code is assignmented to a hospital 
##people from location i visits only one hospital in location j (if present)
for i in range(I):  
    prob.addConstr(sum(Aux[i,j] for j in range(I))==1,name='Aux allocate')
    
for i in range(I):  
    prob.addConstr(sum(Aux[i,j]*post_dist[i][j] for j in range(I))<=10,name='The allocated hospital should be less than 10kms far')
    
###number of bed per hospital proportional to population 

##population from the same outward code is given more priorit
#0.2% of the total population of that postal code + 0.02% of the total population of postal codes that will use this hospital
for j in range(I):
    prob.addConstr(quicksum(0.0002*Tot_pop[i]*Aux[i,j] for i in range(I)) + (X[j]*0.002*Tot_pop[j])<=B[j],name="Beds allocated")

# %% [markdown]
# Number of DV and constraints

# %%
####model optimization
prob.Params.NonConvex = 2
prob.optimize()
#prob.display()
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 1398 rows, 13688 columns and 123192 nonzeros
# Model fingerprint: 0x1ee5f744
# Variable types: 0 continuous, 13688 integer (13572 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+05]
#   Objective range  [4e+00, 2e+04]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 9e+03]
#
# Loaded MIP start from previous solve with objective 261641
#
# Presolve removed 1050 rows and 9566 columns
# Presolve time: 0.08s
# Presolved: 348 rows, 4122 columns, 8592 nonzeros
# Variable types: 0 continuous, 4122 integer (4007 binary)
#
# Root relaxation: objective 2.814624e+05, 1037 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 281462.401    0   42 261641.000 281462.401  7.58%     -    0s
#      0     0 275615.003    0   69 261641.000 275615.003  5.34%     -    0s
#      0     0 275607.901    0   68 261641.000 275607.901  5.34%     -    0s
#      0     0 274668.638    0   75 261641.000 274668.638  4.98%     -    0s
#      0     0 274634.947    0   73 261641.000 274634.947  4.97%     -    0s
#      0     0 273866.225    0   92 261641.000 273866.225  4.67%     -    0s
#      0     0 273760.059    0   87 261641.000 273760.059  4.63%     -    0s
#      0     0 273759.489    0   92 261641.000 273759.489  4.63%     -    0s
#      0     0 269889.893    0  111 261641.000 269889.893  3.15%     -    0s
#      0     0 269873.531    0  105 261641.000 269873.531  3.15%     -    0s
#      0     0 269868.173    0  111 261641.000 269868.173  3.14%     -    0s
#      0     0 269868.173    0  109 261641.000 269868.173  3.14%     -    0s
#      0     0 265974.363    0  116 261641.000 265974.363  1.66%     -    0s
#      0     0 265919.700    0  118 261641.000 265919.700  1.64%     -    0s
#      0     0 265910.040    0  108 261641.000 265910.040  1.63%     -    0s
#      0     0 265909.684    0  110 261641.000 265909.684  1.63%     -    0s
#      0     0 265683.118    0   93 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   41 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   69 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   74 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   78 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   88 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0  104 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0  101 261641.000 265683.118  1.54%     -    0s
#      0     0 265683.118    0   94 261641.000 265683.118  1.54%     -    0s
#      0     0 265679.598    0   89 261641.000 265679.598  1.54%     -    0s
#      0     0 265597.421    0  109 261641.000 265597.421  1.51%     -    0s
#      0     0 265416.688    0  122 261641.000 265416.688  1.44%     -    0s
#      0     0 265416.538    0  120 261641.000 265416.538  1.44%     -    0s
#      0     0 265314.008    0   99 261641.000 265314.008  1.40%     -    0s
#      0     0 265289.421    0   57 261641.000 265289.421  1.39%     -    0s
#      0     0 264375.499    0   47 261641.000 264375.499  1.05%     -    0s
#      0     0 264363.654    0   50 261641.000 264363.654  1.04%     -    0s
#      0     0 264343.452    0   39 261641.000 264343.452  1.03%     -    0s
#      0     0 264338.241    0   39 261641.000 264338.241  1.03%     -    0s
#      0     0 264310.193    0   40 261641.000 264310.193  1.02%     -    1s
#      0     0 264306.617    0   39 261641.000 264306.617  1.02%     -    1s
#      0     0 264278.855    0   74 261641.000 264278.855  1.01%     -    1s
#      0     0 264241.574    0   32 261641.000 264241.574  0.99%     -    1s
#      0     0 262844.373    0   17 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   15 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   28 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   33 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   30 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   30 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   33 261641.000 262844.373  0.46%     -    1s
#      0     0 262844.373    0   22 261641.000 262844.373  0.46%     -    1s
#      0     0 262828.844    0   27 261641.000 262828.844  0.45%     -    1s
#      0     0 262828.844    0   28 261641.000 262828.844  0.45%     -    1s
#      0     0 262828.844    0   28 261641.000 262828.844  0.45%     -    1s
#      0     0 262828.844    0   24 261641.000 262828.844  0.45%     -    1s
#      0     0 262828.844    0   29 261641.000 262828.844  0.45%     -    1s
#      0     0 262828.844    0   35 261641.000 262828.844  0.45%     -    1s
#      0     0 262768.686    0   34 261641.000 262768.686  0.43%     -    1s
#      0     0 262768.686    0   35 261641.000 262768.686  0.43%     -    1s
#      0     0 262768.686    0   43 261641.000 262768.686  0.43%     -    1s
#      0     0 262768.686    0   19 261641.000 262768.686  0.43%     -    1s
#      0     2 262768.686    0   17 261641.000 262768.686  0.43%     -    1s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 9
#   Implied bound: 5
#   Clique: 11
#   MIR: 2
#   StrongCG: 3
#   RLT: 2
#
# Explored 13 nodes (7216 simplex iterations) in 1.48 seconds (0.45 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 261641
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.616410000000e+05, best bound 2.616410000000e+05, gap 0.0000%

# %% [markdown]
# # Results

# %%
##results
count = 0
loc = []
code = []
beds = []
o=0
for v in prob.getVars():
    o +=1
    if v.x==1:
        count += 1
        print(v.varName, '=', v.x)
        if count<=15:
            code.append(v.varName)
        else:
            loc.append(v.varName)
    if  v.x>1:
        print(v.varName, '=', v.x)
        beds.append(int(v.x))
len(loc)
o
# Out:
# ['H1B'] = 1.0
# ['H1E'] = 1.0
# ['H1G'] = 1.0
# ['H1H'] = 1.0
# ['H1K'] = 1.0
# ['H1Z'] = 1.0
# ['H4E'] = 1.0
# ['H4L'] = 1.0
# ['H8N'] = 1.0
# ['H7C'] = 1.0
# ['H7L'] = 1.0
# ['H7N'] = 1.0
# ['H7W'] = 1.0
# ['H9H'] = 1.0
# ['H9W'] = 1.0
# Number of beds in ['H1B'] = 89.0
# Number of beds in ['H1E'] = 127.0
# Number of beds in ['H1G'] = 98.0
# Number of beds in ['H1H'] = 165.0
# Number of beds in ['H1K'] = 82.0
# Number of beds in ['H1Z'] = 99.0
# Number of beds in ['H4E'] = 115.0
# Number of beds in ['H4L'] = 134.0
# Number of beds in ['H8N'] = 80.0
# Number of beds in ['H7C'] = 27.0
# Number of beds in ['H7L'] = 123.0
# Number of beds in ['H7N'] = 90.0
# Number of beds in ['H7W'] = 103.0
# Number of beds in ['H9H'] = 93.0
# Number of beds in ['H9W'] = 72.0
# people from ['H1A']visits['H1B'] = 1.0
# people from ['H1B']visits['H1B'] = 1.0
# people from ['H1C']visits['H1B'] = 1.0
# people from ['H1E']visits['H1B'] = 1.0
# people from ['H1G']visits['H1E'] = 1.0
# people from ['H1H']visits['H1E'] = 1.0
# people from ['H1J']visits['H1B'] = 1.0
# people from ['H1K']visits['H1B'] = 1.0
# people from ['H1L']visits['H1B'] = 1.0
# people from ['H1M']visits['H1B'] = 1.0
# people from ['H1N']visits['H1B'] = 1.0
# people from ['H1P']visits['H1E'] = 1.0
# people from ['H1R']visits['H1E'] = 1.0
# people from ['H1S']visits['H1E'] = 1.0
# people from ['H1T']visits['H1K'] = 1.0
# people from ['H1V']visits['H1H'] = 1.0
# people from ['H1W']visits['H1H'] = 1.0
# people from ['H1X']visits['H1H'] = 1.0
# people from ['H1Y']visits['H1H'] = 1.0
# people from ['H1Z']visits['H4L'] = 1.0
# people from ['H2A']visits['H7C'] = 1.0
# people from ['H2B']visits['H1E'] = 1.0
# people from ['H2C']visits['H7C'] = 1.0
# people from ['H2E']visits['H1H'] = 1.0
# people from ['H2G']visits['H1H'] = 1.0
# people from ['H2H']visits['H1H'] = 1.0
# people from ['H2J']visits['H1Z'] = 1.0
# people from ['H2K']visits['H1Z'] = 1.0
# people from ['H2L']visits['H1Z'] = 1.0
# people from ['H2M']visits['H1H'] = 1.0
# people from ['H2N']visits['H1H'] = 1.0
# people from ['H2P']visits['H1H'] = 1.0
# people from ['H2R']visits['H1H'] = 1.0
# people from ['H2S']visits['H1K'] = 1.0
# people from ['H2T']visits['H1Z'] = 1.0
# people from ['H2V']visits['H4L'] = 1.0
# people from ['H2W']visits['H4E'] = 1.0
# people from ['H2X']visits['H4E'] = 1.0
# people from ['H2Y']visits['H4E'] = 1.0
# people from ['H2Z']visits['H4E'] = 1.0
# people from ['H3A']visits['H4L'] = 1.0
# people from ['H3B']visits['H4E'] = 1.0
# people from ['H3C']visits['H4E'] = 1.0
# people from ['H3E']visits['H4E'] = 1.0
# people from ['H3G']visits['H4L'] = 1.0
# people from ['H3H']visits['H4L'] = 1.0
# people from ['H3J']visits['H4E'] = 1.0
# people from ['H3K']visits['H8N'] = 1.0
# people from ['H3L']visits['H1H'] = 1.0
# people from ['H3M']visits['H1H'] = 1.0
# people from ['H3N']visits['H1H'] = 1.0
# people from ['H3P']visits['H4L'] = 1.0
# people from ['H3R']visits['H1Z'] = 1.0
# people from ['H3S']visits['H1Z'] = 1.0
# people from ['H3T']visits['H4E'] = 1.0
# people from ['H3V']visits['H4E'] = 1.0
# people from ['H3W']visits['H4L'] = 1.0
# people from ['H3X']visits['H4L'] = 1.0
# people from ['H3Y']visits['H4E'] = 1.0
# people from ['H3Z']visits['H4L'] = 1.0
# people from ['H4A']visits['H4L'] = 1.0
# people from ['H4B']visits['H4E'] = 1.0
# people from ['H4C']visits['H4L'] = 1.0
# people from ['H4E']visits['H4E'] = 1.0
# people from ['H4G']visits['H4E'] = 1.0
# people from ['H4H']visits['H8N'] = 1.0
# people from ['H4J']visits['H1H'] = 1.0
# people from ['H4K']visits['H7W'] = 1.0
# people from ['H4L']visits['H7W'] = 1.0
# people from ['H4M']visits['H7W'] = 1.0
# people from ['H4N']visits['H1H'] = 1.0
# people from ['H4P']visits['H4L'] = 1.0
# people from ['H4R']visits['H4L'] = 1.0
# people from ['H4S']visits['H4L'] = 1.0
# people from ['H4V']visits['H4E'] = 1.0
# people from ['H4W']visits['H4L'] = 1.0
# people from ['H4X']visits['H4E'] = 1.0
# people from ['H8N']visits['H4E'] = 1.0
# people from ['H8P']visits['H4E'] = 1.0
# people from ['H8R']visits['H8N'] = 1.0
# people from ['H8S']visits['H8N'] = 1.0
# people from ['H8T']visits['H8N'] = 1.0
# people from ['H8Y']visits['H7W'] = 1.0
# people from ['H8Z']visits['H9H'] = 1.0
# people from ['H7A']visits['H1E'] = 1.0
# people from ['H7B']visits['H7C'] = 1.0
# people from ['H7C']visits['H1E'] = 1.0
# people from ['H7E']visits['H1H'] = 1.0
# people from ['H7G']visits['H1H'] = 1.0
# people from ['H7H']visits['H7L'] = 1.0
# people from ['H7J']visits['H7C'] = 1.0
# people from ['H7K']visits['H7L'] = 1.0
# people from ['H7L']visits['H7L'] = 1.0
# people from ['H7M']visits['H1H'] = 1.0
# people from ['H7N']visits['H1H'] = 1.0
# people from ['H7P']visits['H7L'] = 1.0
# people from ['H7R']visits['H7L'] = 1.0
# people from ['H7S']visits['H7W'] = 1.0
# people from ['H7T']visits['H7L'] = 1.0
# people from ['H7V']visits['H4L'] = 1.0
# people from ['H7W']visits['H7L'] = 1.0
# people from ['H7X']visits['H7N'] = 1.0
# people from ['H7Y']visits['H7W'] = 1.0
# people from ['H9A']visits['H9H'] = 1.0
# people from ['H9B']visits['H9H'] = 1.0
# people from ['H9C']visits['H9W'] = 1.0
# people from ['H9E']visits['H9H'] = 1.0
# people from ['H9G']visits['H9H'] = 1.0
# people from ['H9H']visits['H9H'] = 1.0
# people from ['H9J']visits['H9H'] = 1.0
# people from ['H9K']visits['H9W'] = 1.0
# people from ['H9P']visits['H9W'] = 1.0
# people from ['H9R']visits['H9H'] = 1.0
# people from ['H9S']visits['H9W'] = 1.0
# people from ['H9W']visits['H9W'] = 1.0
# people from ['H9X']visits['H9W'] = 1.0
# 13688

# %% [markdown]
# #### There are a total of 15 hospitals that get constructed.

# %% [markdown]
# ### Binding and Non-Binding Constraint

# %%
count = 0
for c in prob.getConstrs():
    if c.Slack > 1e-6:
        print(c.ConstrName, ": The slack is ", round(c.Slack))
        count += 1
    
count
# Out:
# Budget : The slack is  3
# R3 : The slack is  99911
# R5 : The slack is  99873
# R6 : The slack is  99902
# R7 : The slack is  99835
# R9 : The slack is  99918
# R21 : The slack is  99901
# R65 : The slack is  99885
# R70 : The slack is  99866
# R79 : The slack is  99920
# R88 : The slack is  99973
# R94 : The slack is  99877
# R96 : The slack is  99910
# R102 : The slack is  99897
# R110 : The slack is  99907
# R116 : The slack is  99928
# Aux allocate : The slack is  5
# Aux allocate : The slack is  10
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  10
# Aux allocate : The slack is  7
# Aux allocate : The slack is  6
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  4
# Aux allocate : The slack is  6
# Aux allocate : The slack is  6
# Aux allocate : The slack is  7
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  10
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  4
# Aux allocate : The slack is  5
# Aux allocate : The slack is  7
# Aux allocate : The slack is  10
# Aux allocate : The slack is  7
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  10
# Aux allocate : The slack is  4
# Beds allocated : The slack is  37
# Beds allocated : The slack is  77
# Beds allocated : The slack is  88
# Beds allocated : The slack is  65
# Beds allocated : The slack is  63
# Beds allocated : The slack is  64
# Beds allocated : The slack is  55
# Beds allocated : The slack is  67
# Beds allocated : The slack is  53
# Beds allocated : The slack is  16
# Beds allocated : The slack is  75
# Beds allocated : The slack is  76
# Beds allocated : The slack is  75
# Beds allocated : The slack is  60
# Beds allocated : The slack is  53
# Budget : The slack is  3
# R469 : The slack is  99911
# R471 : The slack is  99873
# R472 : The slack is  99902
# R473 : The slack is  99835
# R475 : The slack is  99918
# R487 : The slack is  99901
# R531 : The slack is  99885
# R536 : The slack is  99866
# R545 : The slack is  99920
# R554 : The slack is  99973
# R560 : The slack is  99877
# R562 : The slack is  99910
# R568 : The slack is  99897
# R576 : The slack is  99907
# R582 : The slack is  99928
# Aux allocate : The slack is  5
# Aux allocate : The slack is  10
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  3
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  2
# Aux allocate : The slack is  3
# Aux allocate : The slack is  10
# Aux allocate : The slack is  7
# Aux allocate : The slack is  6
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  1
# Aux allocate : The slack is  4
# Aux allocate : The slack is  6
# Aux allocate : The slack is  6
# Aux allocate : The slack is  7
# Aux allocate : The slack is  5
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  1
# Aux allocate : The slack is  5
# Aux allocate : The slack is  3
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  2
# Aux allocate : The slack is  10
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  2
# Aux allocate : The slack is  5
# Aux allocate : The slack is  4
# Aux allocate : The slack is  5
# Aux allocate : The slack is  7
# Aux allocate : The slack is  10
# Aux allocate : The slack is  7
# Aux allocate : The slack is  2
# Aux allocate : The slack is  4
# Aux allocate : The slack is  1
# Aux allocate : The slack is  10
# Aux allocate : The slack is  4
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  8
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  14
# Beds allocated : The slack is  18
# Budget : The slack is  3
# Beds only if hopsital is present : The slack is  99911
# Beds only if hopsital is present : The slack is  99873
# Beds only if hopsital is present : The slack is  99902
# Beds only if hopsital is present : The slack is  99835
# Beds only if hopsital is present : The slack is  99918
# Beds only if hopsital is present : The slack is  99901
# Beds only if hopsital is present : The slack is  99885
# Beds only if hopsital is present : The slack is  99866
# Beds only if hopsital is present : The slack is  99920
# Beds only if hopsital is present : The slack is  99973
# Beds only if hopsital is present : The slack is  99877
# Beds only if hopsital is present : The slack is  99910
# Beds only if hopsital is present : The slack is  99897
# Beds only if hopsital is present : The slack is  99907
# Beds only if hopsital is present : The slack is  99928
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  10
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  10
# The allocated hospital should be less than 10kms far : The slack is  7
# The allocated hospital should be less than 10kms far : The slack is  6
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  6
# The allocated hospital should be less than 10kms far : The slack is  6
# The allocated hospital should be less than 10kms far : The slack is  7
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  3
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  10
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  5
# The allocated hospital should be less than 10kms far : The slack is  7
# The allocated hospital should be less than 10kms far : The slack is  10
# The allocated hospital should be less than 10kms far : The slack is  7
# The allocated hospital should be less than 10kms far : The slack is  2
# The allocated hospital should be less than 10kms far : The slack is  4
# The allocated hospital should be less than 10kms far : The slack is  1
# The allocated hospital should be less than 10kms far : The slack is  10
# The allocated hospital should be less than 10kms far : The slack is  4
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  1
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  8
# Beds allocated : The slack is  0
# Beds allocated : The slack is  0
# Beds allocated : The slack is  14
# Beds allocated : The slack is  18
# 360

# %% [markdown]
# ### Location of the Hospitals

# %%
###Data preprocessing for visualization
import re
final = []
final1 = []
final2 = []
result =''
for i in range(15):
    sampleStr = code[i]
    mk1 = sampleStr.find("['")+2
    mk2 = sampleStr.find("']", mk1)
    result = sampleStr[ mk1 : mk2 ]
    final.append(result)                  ###contains the postal codes of all the locations where hospital is to be built 
    
soln ={'Outward codes':final,"beds":beds} 

sol = pd.DataFrame(data=soln)

for i in range(len(loc)):
    sampleStr = loc[i]
    mk1 = sampleStr.find("['")+2
    mk2 = sampleStr.find("']visits", mk1)
    result1 = sampleStr[ mk1 : mk2 ]
    final1.append(result1) 
    
    sampleStr2 = loc[i]
    mk12 = sampleStr2.find("visits['")+8
    mk22 = sampleStr2.find("'] =1.0", mk12)-1
    result2 = sampleStr[ mk12 : mk22 ]
    final2.append(result2)     

so ={'Outward codes':final1,"Hospital":final2}

# %%
import pgeocode
nomi = pgeocode.Nominatim('ca')
df = nomi.query_postal_code(final)
df["No. of beds"] = beds
print("\033[1m" + "Outward codes that will have hospitals" + "\033[0m")
df[["postal_code","place_name",'No. of beds']]
# Out:
# Outward codes that will have hospitals
#    postal_code                      place_name  No. of beds
# 0          H1B                   Montreal East           89
# 1          H1E  Rivière-Des-Prairies Southwest          127
# 2          H1G            Montreal North North           98
# 3          H1H            Montreal North South          165
# 4          H1K                      Anjou East           82
# 5          H1Z               Saint-Michel West           99
# 6          H4E                     Ville Émard          115
# 7          H4L   Saint-Laurent Inner Northeast          134
# 8          H8N               LaSalle Northwest           80
# 9          H7C           Saint-Vincent-de-Paul           27
# 10         H7L                     Sainte-Rose          123
# 11         H7N               Laval-des-Rapides           90
# 12         H7W                  Chomedey South          103
# 13         H9H                Sainte-Geneviève           93
# 14         H9W                    Beaconsfield           72

# %%
print("\033[1m" + "People in Outward codes visit its respective hospitals" + "\033[0m")
locat= pd.DataFrame(data=so) 
locat.head(20)
# Out:
# People in Outward codes visit its respective hospitals
#    Outward codes Hospital
# 0            H1A      H1B
# 1            H1B      H1B
# 2            H1C      H1B
# 3            H1E      H1B
# 4            H1G      H1E
# 5            H1H      H1E
# 6            H1J      H1B
# 7            H1K      H1B
# 8            H1L      H1B
# 9            H1M      H1B
# 10           H1N      H1B
# 11           H1P      H1E
# 12           H1R      H1E
# 13           H1S      H1E
# 14           H1T      H1K
# 15           H1V      H1H
# 16           H1W      H1H
# 17           H1X      H1H
# 18           H1Y      H1H
# 19           H1Z      H4L

# %%
##extract montreal's base map location coordinates
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="location_details")
location = geolocator.geocode("Montreal,Canada")

# %%
###create a map to indicate the choosen hospital locations
import folium
map=folium.Map(location=(location.latitude, location.longitude))
for i in range(11):
    map.add_child(folium.Marker(location=[df['latitude'][i],df['longitude'][i]],popup=df['place_name'][i],icon=folium.Icon(color='green')))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e0bb75c6d84bad3ee03e8680b2030dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e0bb75c6d84bad3ee03e8680b2030dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e0bb75c6d84bad3ee03e8680b2030dd = L.map(
#                 &quot;map_3e0bb75c6d84bad3ee03e8680b2030dd&quot;,
#                 {
#                     center: [45.5031824, -73.5698065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9a22ba286f7c49c9657ae74914a32f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e0bb75c6d84bad3ee03e8680b2030dd);
#
#
#             var marker_652b81ce0515edcdf16f5b15a83e1338 = L.marker(
#                 [45.632, -73.5075],
#                 {}
#             ).addTo(map_3e0bb75c6d84bad3ee03e8680b2030dd);
#
#
#             var icon_a6704806d2651f32adb2d06f6a32d0a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_652b81ce0515edcdf16f5b15a83e1338.setIcon(icon_a6704806d2651f32adb2d06f6a32d0a8);
#
#
#         var popup_2eb391418e815b881223a95cbeaaa7f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb93714973e9c6731dc96518e4a54a0d = $(`&lt;div id=&quot;html_cb93714973e9c6731dc96518e4a54a0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montreal East&lt;/div&gt;`)[0];
#                 popup_2eb391418e815b881223a95cbeaaa7f8.setContent(html_cb93714973e9c6731dc96518e4a54a0d);
#
#
#
#         marker_652b81ce0515edcdf16f5b15a83e1338.bindPopup(popup_2eb391418e815b881223a95cbeaaa7f8)
#         ;
#
#
#
#
#             var marker_88b9fb22b7a20355e590cae2179ef492 = L.marker(
#                 [45.6342, -73.5842],
#                 {}
#             ).addTo(map_3e0bb75c6d84bad3ee03e8680b2030dd);
#
#
#             var icon_c482fc57048c05e12dc0537bd941cd38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88b9fb22b7a20355e590cae2179ef492.setIcon(icon_c482fc57048c05e12dc0537bd941cd38);
#
#
#         var popup_8218cfb1bd6222c40f44c225ba073c9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b005d4eb169622c809843f7adcbf4632 = $(`&lt;div id=&quot;html_b005d4eb169622c809843f7adcbf4632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rivière-Des-Prairies Southwest&lt;/div&gt;`)[0];
#                 popup_8218cfb1bd6222c40f44c225ba073c9e.setContent(html_b005d4eb169622c809843f7adcbf4632);
#
#
#
#         marker_88b9fb22b7a20355e590cae2179ef492.bindPopup(popup_8218cfb1bd6222c40f44c225ba073c9e)
#         ;
#
#
#
#
#             var marker_fd4403600c1bddefd9480d67f4ed4309 = L.marker(
#                 [45.6109, -73.6211],
#                 {}
#             ).addTo(map_3e0bb75c6d84bad3ee03e8680b2030dd);
#
#
#             var icon_bcfce80c270897bdb2e02121e50e6c7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd4403600c1bddefd9480d67f4ed4309.setIcon(icon_bcfce80c270897bdb2e02121e50e6c7e);
#
#
#         var popup_56c067ddd19d9e3fb73f76fb38fa33ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33b919b5455784b8923f73c0e9fa1b88 = $(`&lt;div id=&quot;html_33b919b5455784b8923f73c0e9fa1b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montreal North North&lt;/div&gt;`)[0];
#                 popup_56c067ddd19d9e3fb73f76fb38fa33ca.setContent(html_33b919b5455784b8923f73c0e9fa1b88);
#
#
#
#         marker_fd4403600c1bddefd9480d67f4ed4309.bindPopup(popup_56c067ddd19d9e3fb73f76fb38fa33ca)
#         ;
#
#
#
#
#             var marker_78b610462d4b201aa66dfe048596e54d = L.marker(
#                 [45.5899, -73.6389],
#                 {}
#             ).addTo(map_3e0bb75c6d84bad3ee03e8680b2030dd);
#
#
#             var icon_499b5d47437a95dfdf13a193be2e83a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quo

# %%
###calculating the distance between various postal codes
import geopy.distance
dist=[]
cor_1 = []
cor_2 = []
for i in range(12):
    for j in range(i+1):
        if(i!=j):
            coords_1 = (df['latitude'][i],df['longitude'][i])
            coords_2 = (df['latitude'][j],df['longitude'][j])
            dist.append(geopy.distance.geodesic(coords_1, coords_2).km)
            cor_1.append(df["postal_code"][i])
            cor_2.append(df["postal_code"][j])
            
distance = {"Hospital location 1":cor_1,"Hospital location 2":cor_2,"distance":dist}
sol = pd.DataFrame(data=distance)

print("\033[1m" + "Top Closest hospitals" + "\033[0m")
sol.sort_values(['distance']).head(10)
# Out:
# Top Closest hospitals
#    Hospital location 1 Hospital location 2  distance
# 38                 H7C                 H1G  2.287803
# 34                 H8N                 H4E  2.577094
# 13                 H1Z                 H1H  2.628785
# 5                  H1H                 H1G  2.715919
# 39                 H7C                 H1H  3.095864
# 2                  H1G                 H1E  3.871416
# 62                 H7N                 H4L  3.887823
# 6                  H1K                 H1B  3.966062
# 7                  H1K                 H1E  3.967563
# 12                 H1Z                 H1G  4.613107

# %%
print("\033[1m" + "Top farthest hospitals" + "\033[0m")
sol.sort_values(['distance'],ascending=False).head(10)
# Out:
# Top farthest hospitals
#    Hospital location 1 Hospital location 2   distance
# 53                 H7L                 H8N  23.517940
# 28                 H8N                 H1B  23.327924
# 51                 H7L                 H4E  23.055066
# 29                 H8N                 H1E  21.999875
# 45                 H7L                 H1B  21.512511
# 15                 H4E                 H1B  20.958411
# 16                 H4E                 H1E  19.992394
# 44                 H7C                 H8N  19.989674
# 32                 H8N                 H1K  19.946389
# 30                 H8N                 H1G  19.216482

# %%
##extract montreal's base map location coordinates
import pgeocode
nomi = pgeocode.Nominatim('ca')
df2 = nomi.query_postal_code(final1)

# %%
###create a map to indicate the choosen hospital locations
import folium
map2=folium.Map(location=(location.latitude, location.longitude))
for i in range(116):
    map2.add_child(folium.Marker(location=[df['latitude'][df.postal_code=="H1B"],df['longitude'][df.postal_code=="H1B"]],popup=df['place_name'][df.postal_code=="H1B"],icon=folium.Icon(color='blue')))
    if final2[i] == "H1B":
        map2.add_child(folium.Marker(location=[df2['latitude'][i],df2['longitude'][i]],popup=df2['place_name'][i],icon=folium.Icon(color='green')))
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d97a5ce02ea4a31ff7b1c41784de7fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d97a5ce02ea4a31ff7b1c41784de7fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d97a5ce02ea4a31ff7b1c41784de7fe = L.map(
#                 &quot;map_1d97a5ce02ea4a31ff7b1c41784de7fe&quot;,
#                 {
#                     center: [45.5031824, -73.5698065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b157249016d13276c4cdeaea22ee904e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d97a5ce02ea4a31ff7b1c41784de7fe);
#
#
#             var marker_d58854f2ba922dd42ccb0d89f60b1e3d = L.marker(
#                 [45.632, -73.5075],
#                 {}
#             ).addTo(map_1d97a5ce02ea4a31ff7b1c41784de7fe);
#
#
#             var icon_87b81c2cd65be956f28028c5e8884414 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d58854f2ba922dd42ccb0d89f60b1e3d.setIcon(icon_87b81c2cd65be956f28028c5e8884414);
#
#
#         var popup_815a49b33d9b09771da3d4fea06baae7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f36fe13e758a124dbe4338bdd394144 = $(`&lt;div id=&quot;html_6f36fe13e758a124dbe4338bdd394144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    Montreal East Name: place_name, dtype: object&lt;/div&gt;`)[0];
#                 popup_815a49b33d9b09771da3d4fea06baae7.setContent(html_6f36fe13e758a124dbe4338bdd394144);
#
#
#
#         marker_d58854f2ba922dd42ccb0d89f60b1e3d.bindPopup(popup_815a49b33d9b09771da3d4fea06baae7)
#         ;
#
#
#
#
#             var marker_c6dee46eaee6d28197c616dac69aa1e2 = L.marker(
#                 [45.6753, -73.5016],
#                 {}
#             ).addTo(map_1d97a5ce02ea4a31ff7b1c41784de7fe);
#
#
#             var icon_508dbe07bda14b7e6aa87218d5746c68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6dee46eaee6d28197c616dac69aa1e2.setIcon(icon_508dbe07bda14b7e6aa87218d5746c68);
#
#
#         var popup_e73200e82318a77b6b892cfd457da3d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5ebbf503910324a0635abaf194b4120 = $(`&lt;div id=&quot;html_f5ebbf503910324a0635abaf194b4120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pointe-Aux-Trembles&lt;/div&gt;`)[0];
#                 popup_e73200e82318a77b6b892cfd457da3d0.setContent(html_f5ebbf503910324a0635abaf194b4120);
#
#
#
#         marker_c6dee46eaee6d28197c616dac69aa1e2.bindPopup(popup_e73200e82318a77b6b892cfd457da3d0)
#         ;
#
#
#
#
#             var marker_72e9cdbfd65ec1ff39b2337bebd18014 = L.marker(
#                 [45.632, -73.5075],
#                 {}
#             ).addTo(map_1d97a5ce02ea4a31ff7b1c41784de7fe);
#
#
#             var icon_925b2ef3a123cf001c43b77fe209962e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72e9cdbfd65ec1ff39b2337bebd18014.setIcon(icon_925b2ef3a123cf001c43b77fe209962e);
#
#
#         var popup_b56dfe19cdd97290bed0eb48d41cfb76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4173e89c0cbd19d52f3f492d37e723b = $(`&lt;div id=&quot;html_d4173e89c0cbd19d52f3f492d37e723b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    Montreal East Name: place_name, dtype: object&lt;/div&gt;`)[0];
#                 popup_b56dfe19cdd97290bed0eb48d41cfb76.setContent(html_d4173e89c0cbd19d52f3f492d37e723b);
#
#
#
#         marker_72e9cdbfd65ec1ff39b2337bebd18014.bindPopup(popup_b56dfe19cdd97290bed0eb48d41cfb76)
#         ;
#
#
#
#
#             var marker_04fb5ceea6fd7a7b3671552034f834d8 = L.marker(
#                 [45.632, -73.5075],
#                 {}
#             ).addTo(map_1d97a5ce02ea4a31ff7b1c41784de7fe);
#
#
#             var icon_a9dc27833e629009543c27438e05cffa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quo

# %%
###create a map to indicate the choosen hospital locations
import folium
map2=folium.Map(location=(location.latitude, location.longitude))
for i in range(116):
    map2.add_child(folium.Marker(location=[df['latitude'][df.postal_code=="H9H"],df['longitude'][df.postal_code=="H9H"]],popup=df['place_name'][df.postal_code=="H9H"],icon=folium.Icon(color='blue')))
    if final2[i] == "H9H":
        map2.add_child(folium.Marker(location=[df2['latitude'][i],df2['longitude'][i]],popup=df2['place_name'][i],icon=folium.Icon(color='green')))
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e93dd952750088ef6f5d6ddfbc9cf59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e93dd952750088ef6f5d6ddfbc9cf59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e93dd952750088ef6f5d6ddfbc9cf59 = L.map(
#                 &quot;map_9e93dd952750088ef6f5d6ddfbc9cf59&quot;,
#                 {
#                     center: [45.5031824, -73.5698065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e4cac90bd68858dd3d17c788f225b89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e93dd952750088ef6f5d6ddfbc9cf59);
#
#
#             var marker_a91d687420c75a50091f7368f656d5b6 = L.marker(
#                 [45.4683, -73.8565],
#                 {}
#             ).addTo(map_9e93dd952750088ef6f5d6ddfbc9cf59);
#
#
#             var icon_3350b99b4a498738f44b426a1d123f0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a91d687420c75a50091f7368f656d5b6.setIcon(icon_3350b99b4a498738f44b426a1d123f0a);
#
#
#         var popup_83dbaf819e7cf1c0f2699cb612608bbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54fba88535f333fbcc0e47a16f8acfbf = $(`&lt;div id=&quot;html_54fba88535f333fbcc0e47a16f8acfbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13    Sainte-Geneviève Name: place_name, dtype: object&lt;/div&gt;`)[0];
#                 popup_83dbaf819e7cf1c0f2699cb612608bbe.setContent(html_54fba88535f333fbcc0e47a16f8acfbf);
#
#
#
#         marker_a91d687420c75a50091f7368f656d5b6.bindPopup(popup_83dbaf819e7cf1c0f2699cb612608bbe)
#         ;
#
#
#
#
#             var marker_cbf6797c4d7d4232745bbd1180602d4b = L.marker(
#                 [45.4683, -73.8565],
#                 {}
#             ).addTo(map_9e93dd952750088ef6f5d6ddfbc9cf59);
#
#
#             var icon_a98c97844b684d4ab115935d3617b67c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbf6797c4d7d4232745bbd1180602d4b.setIcon(icon_a98c97844b684d4ab115935d3617b67c);
#
#
#         var popup_2e3516797babbef39263cdf6c05dbb32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21b6a99834cde5f87e133e43e77398ff = $(`&lt;div id=&quot;html_21b6a99834cde5f87e133e43e77398ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13    Sainte-Geneviève Name: place_name, dtype: object&lt;/div&gt;`)[0];
#                 popup_2e3516797babbef39263cdf6c05dbb32.setContent(html_21b6a99834cde5f87e133e43e77398ff);
#
#
#
#         marker_cbf6797c4d7d4232745bbd1180602d4b.bindPopup(popup_2e3516797babbef39263cdf6c05dbb32)
#         ;
#
#
#
#
#             var marker_a89ca86f7bca82c9cedf2adcbdeb1d61 = L.marker(
#                 [45.4683, -73.8565],
#                 {}
#             ).addTo(map_9e93dd952750088ef6f5d6ddfbc9cf59);
#
#
#             var icon_85392772bc6c62c98df0ae3a1d8f3456 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a89ca86f7bca82c9cedf2adcbdeb1d61.setIcon(icon_85392772bc6c62c98df0ae3a1d8f3456);
#
#
#         var popup_143d44362582b798335a024c0fa7891a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3dd3b7bcae899237c855e9ec71bc97f5 = $(`&lt;div id=&quot;html_3dd3b7bcae899237c855e9ec71bc97f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13    Sainte-Geneviève Name: place_name, dtype: object&lt;/div&gt;`)[0];
#                 popup_143d44362582b798335a024c0fa7891a.setContent(html_3dd3b7bcae899237c855e9ec71bc97f5);
#
#
#
#         marker_a89ca86f7bca82c9cedf2adcbdeb1d61.bindPopup(popup_143d44362582b798335a024c0fa7891a)
#         ;
#
#
#
#
#             var marker_141824bda51c17b6d44d5bf19411842d = L.marker(
#                 [45.4683, -73.8565],
#                 {}
#             ).addTo(map_9e93dd952750088ef6f5d6ddfbc9cf59);
#
#
#             var icon_130e987ec85d3544cffbf0542b1ccc82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&
